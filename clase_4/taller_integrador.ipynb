# %% [markdown]
# # Taller integrador

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\santi\appdata\local\programs\python\python314\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\santi\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\santi\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\santi\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\santi\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("estudiantes_ml_2026_.csv")
df.head(10) #Permite mostrar una parte pequeña de los datos
# Out:
#              nombre  edad            ciudad       pais genero nivel_previo  \
# 0  Valentina Torres    28            Bogotá   Colombia      F   intermedio
# 1    Carlos Mendoza    34  Ciudad de México     México      M       básico
# 2        Anita Ruiz    25          Medellín   Colombia      F       básico
# 3     Jorge Ramírez    41              Lima       Perú      M     avanzado
# 4      Daniela Soto    29          Santiago      Chile      F   intermedio
# 5     Miguel Flores    37       Guadalajara     México      M       básico
# 6       Laura Gómez    31              Cali   Colombia      F       básico
# 7  Sebastián Castro    26      Buenos Aires  Argentina      M   intermedio
# 8     Camila Vargas    33             Quito    Ecuador      F       básico
# 9    Andrés Herrera    45      Barranquilla   Colombia      M     avanzado
#
#    horas_estudio_semana  promedio  modulos_completados  activo fecha_ingreso  \
# 0                    12       8.7                    3    True    2024-09-01
# 1                     8       5.2                    1    True    2024-09-01
# 2                    15       9.1                    3    True    2024-09-01
# 3                     6       7.4                    2    True    2024-09-01
# 4                    10       6.8                    2    True    2024-09-01
# 5                     4       4.1                    1   False    2024-09-01
# 6                    11       7.9                    2    True    2024-09-01
# 7                    14       8.3                    3    True    2024-09-01
# 8                     9       6.1                    2    True    2024-09-01
# 9                     5       7.2                    2    True    2024-09-01
#
#    trabaja_actualmente  salario_usd            objetivo
# 0                 True         1200   cambio de carrera
# 1                 True          800     ascenso laboral
# 2                False            0  primer empleo tech
# 3                 True         2100      emprendimiento
# 4                 True         1500   cambio de carrera
# 5                 True          900     ascenso laboral
# 6                False            0   cambio de carrera
# 7                 True         1100      emprendimiento
# 8                 True          700  primer empleo tech
# 9                 True         2500      emprendimiento

# %%
print(df.shape)

print(df.columns.tolist())
# Out:
# (25, 14)
# ['nombre', 'edad', 'ciudad', 'pais', 'genero', 'nivel_previo', 'horas_estudio_semana', 'promedio', 'modulos_completados', 'activo', 'fecha_ingreso', 'trabaja_actualmente', 'salario_usd', 'objetivo']

# %%
df["nombre"]
# Out:
# 0      Valentina Torres
# 1        Carlos Mendoza
# 2            Anita Ruiz
# 3         Jorge Ramírez
# 4          Daniela Soto
# 5         Miguel Flores
# 6           Laura Gómez
# 7      Sebastián Castro
# 8         Camila Vargas
# 9        Andrés Herrera
# 10        Paula Jiménez
# 11        Ricardo López
# 12    Isabella Martínez
# 13        Fernando Díaz
# 14       Natalia Romero
# 15        Diego Morales
# 16          Sofía Reyes
# 17      Alejandro Núñez
# 18     Mariana Castillo
# 19           Luis Prada
# 20       Carlos Mendoza
# 21       Andrea Fuentes
# 22        Tomás Aguirre
# 23         Valeria Peña
# 24          José Moreno
# Name: nombre, dtype: str

# %%
print(df.loc[0,'nombre'])
# Out:
# Valentina Torres

# %%
df.describe()
# Out:
#             edad  horas_estudio_semana   promedio  modulos_completados  \
# count  25.000000              25.00000  23.000000            25.000000
# mean   33.400000               9.52000   7.269565             2.000000
# std     7.697402               4.06325   1.458653             0.866025
# min    23.000000               3.00000   4.100000             0.000000
# 25%    28.000000               6.00000   6.250000             1.000000
# 50%    31.000000               9.00000   7.400000             2.000000
# 75%    38.000000              12.00000   8.400000             3.000000
# max    52.000000              18.00000   9.400000             3.000000
#
#        salario_usd
# count    25.000000
# mean   1010.000000
# std     898.841847
# min       0.000000
# 25%       0.000000
# 50%     800.000000
# 75%    1500.000000
# max    3200.000000

# %%
df[df['promedio'] > 8.0]
# Out:
#                nombre  edad        ciudad       pais genero nivel_previo  \
# 0    Valentina Torres    28        Bogotá   Colombia      F   intermedio
# 2          Anita Ruiz    25      Medellín   Colombia      F       básico
# 7    Sebastián Castro    26  Buenos Aires  Argentina      M   intermedio
# 10      Paula Jiménez    27    Montevideo    Uruguay      F       básico
# 12  Isabella Martínez    24      Medellín   Colombia      F       básico
# 17    Alejandro Núñez    23        Bogotá   Colombia      M       básico
# 21     Andrea Fuentes    26        Bogotá   Colombia      F   intermedio
# 23       Valeria Peña    29   Bucaramanga   Colombia      F       básico
#
#     horas_estudio_semana  promedio  modulos_completados  activo fecha_ingreso  \
# 0                     12       8.7                    3    True    2024-09-01
# 2                     15       9.1                    3    True    2024-09-01
# 7                     14       8.3                    3    True    2024-09-01
# 10                    13       8.5                    3    True    2024-09-01
# 12                    16       9.4                    3    True    2024-09-01
# 17                    18       9.2                    3    True    2024-09-01
# 21                    12       8.1                    3    True    2024-09-01
# 23                    14       8.9                    3    True    2024-09-01
#
#     trabaja_actualmente  salario_usd            objetivo
# 0                  True         1200   cambio de carrera
# 2                 False            0  primer empleo tech
# 7                  True         1100      emprendimiento
# 10                False            0   cambio de carrera
# 12                False            0  primer empleo tech
# 17                False            0  primer empleo tech
# 21                False            0   cambio de carrera
# 23                False            0  primer empleo tech

# %%
df[(df['promedio']>8.0) & (df['activo'] == True)]
# Out:
#                nombre  edad        ciudad       pais genero nivel_previo  \
# 0    Valentina Torres    28        Bogotá   Colombia      F   intermedio
# 2          Anita Ruiz    25      Medellín   Colombia      F       básico
# 7    Sebastián Castro    26  Buenos Aires  Argentina      M   intermedio
# 10      Paula Jiménez    27    Montevideo    Uruguay      F       básico
# 12  Isabella Martínez    24      Medellín   Colombia      F       básico
# 17    Alejandro Núñez    23        Bogotá   Colombia      M       básico
# 21     Andrea Fuentes    26        Bogotá   Colombia      F   intermedio
# 23       Valeria Peña    29   Bucaramanga   Colombia      F       básico
#
#     horas_estudio_semana  promedio  modulos_completados  activo fecha_ingreso  \
# 0                     12       8.7                    3    True    2024-09-01
# 2                     15       9.1                    3    True    2024-09-01
# 7                     14       8.3                    3    True    2024-09-01
# 10                    13       8.5                    3    True    2024-09-01
# 12                    16       9.4                    3    True    2024-09-01
# 17                    18       9.2                    3    True    2024-09-01
# 21                    12       8.1                    3    True    2024-09-01
# 23                    14       8.9                    3    True    2024-09-01
#
#     trabaja_actualmente  salario_usd            objetivo
# 0                  True         1200   cambio de carrera
# 2                 False            0  primer empleo tech
# 7                  True         1100      emprendimiento
# 10                False            0   cambio de carrera
# 12                False            0  primer empleo tech
# 17                False            0  primer empleo tech
# 21                False            0   cambio de carrera
# 23                False            0  primer empleo tech

# %% [markdown]
# # Limpiar DataSet con criterio
# Detectar si hay un problema

# %%
df.isnull().sum()
# Out:
# nombre                  0
# edad                    0
# ciudad                  0
# pais                    0
# genero                  0
# nivel_previo            0
# horas_estudio_semana    0
# promedio                2
# modulos_completados     0
# activo                  0
# fecha_ingreso           0
# trabaja_actualmente     0
# salario_usd             0
# objetivo                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nombre                25 non-null     str
#  1   edad                  25 non-null     int64
#  2   ciudad                25 non-null     str
#  3   pais                  25 non-null     str
#  4   genero                25 non-null     str
#  5   nivel_previo          25 non-null     str
#  6   horas_estudio_semana  25 non-null     int64
#  7   promedio              23 non-null     float64
#  8   modulos_completados   25 non-null     int64
#  9   activo                25 non-null     bool
#  10  fecha_ingreso         25 non-null     str
#  11  trabaja_actualmente   25 non-null     bool
#  12  salario_usd           25 non-null     int64
#  13  objetivo              25 non-null     str
# dtypes: bool(2), float64(1), int64(4), str(7)
# memory usage: 2.5 KB

# %% [markdown]
# # DataSet 2

# %%
titanic = pd.read_csv("titanic_clase4.csv")
titanic.head(10)
# Out:
#             nombre  sobrevivio  clase    sexo  edad  tarifa embarcacion cabina
# 0      Jack Dawson           0      3    male  20.0    7.25           S    NaN
# 1      Rose DeWitt           1      1  female  17.0  512.33           C    B57
# 2       John Smith           0      2    male  35.0   13.00           S    NaN
# 3     Mary Johnson           1      1  female  28.0   76.29           C    C85
# 4     Thomas Brown           0      3    male   NaN    8.05           S    NaN
# 5  Elisabeth Jones           1      1  female  45.0   35.50           S   C103
# 6    William Davis           0      3    male  23.0    7.92           Q    NaN
# 7     Sarah Wilson           1      2  female  31.0   21.00           S    NaN
# 8     James Miller           0      3    male   NaN    7.75           Q    NaN
# 9       Emma Moore           1      1  female  22.0  151.55           S    B45

# %%
print(titanic.shape)
titanic.info()
# Out:
# (31, 8)
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nombre       31 non-null     str
#  1   sobrevivio   31 non-null     int64
#  2   clase        31 non-null     int64
#  3   sexo         31 non-null     str
#  4   edad         27 non-null     float64
#  5   tarifa       31 non-null     float64
#  6   embarcacion  31 non-null     str
#  7   cabina       11 non-null     str
# dtypes: float64(2), int64(2), str(4)
# memory usage: 2.1 KB

# %%
titanic.describe()
# Out:
#        sobrevivio      clase       edad      tarifa
# count   31.000000  31.000000  27.000000   31.000000
# mean     0.516129   2.129032  33.222222   52.375161
# std      0.508001   0.921663  11.056962   98.678691
# min      0.000000   1.000000  17.000000    7.250000
# 25%      0.000000   1.000000  25.000000    7.920000
# 50%      1.000000   2.000000  33.000000   13.000000
# 75%      1.000000   3.000000  39.000000   55.700000
# max      1.000000   3.000000  62.000000  512.330000

# %%
titanic.isnull().sum()
# Out:
# nombre          0
# sobrevivio      0
# clase           0
# sexo            0
# edad            4
# tarifa          0
# embarcacion     0
# cabina         20
# dtype: int64

# %%
titanic_nuevo = titanic.drop(columns=['cabina'])
titanic_nuevo = titanic_nuevo.drop_duplicates()
media_edad = titanic_nuevo['edad'].median()
titanic_nuevo['edad'].fillna(media_edad)

print(f"Info limpia {titanic_nuevo.shape}")
# Out:
# Info limpia (30, 7)

# %%
tasa = titanic_nuevo['sobrevivio'].mean()
print(tasa)
print(f"Tasa de supervivencia: {tasa:.1%}") # :.0% pone el valor en porcentaje
# Out:
# 0.5333333333333333
# Tasa de supervivencia: 53.3%

# %%
#Sobrevivieron mas mujeres o mas hombres?
titanic_nuevo.groupby('sexo')['sobrevivio'].mean()
# Out:
# sexo
# female    0.933333
# male      0.133333
# Name: sobrevivio, dtype: float64

# %%
#La clase determinó la supervivencia
titanic_nuevo.groupby('clase')['sobrevivio'].mean()
# Out:
# clase
# 1    1.000000
# 2    0.750000
# 3    0.133333
# Name: sobrevivio, dtype: float64

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\santi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\santi\appdata\roaming\python\python314\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\santi\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\santi\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.3 MB 8.3 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.3 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 14.5 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 16.5 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.1.1-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    --------------------- ------------------ 3.9/7.2 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 18.2 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Gráfica 1

# %%
supervivencia_sexo = titanic_nuevo.groupby('sexo')['sobrevivio'].mean()

plt.Figure(figsize=(7, 5))
supervivencia_sexo.plot(
    kind = "bar",
    color = ["#DD8452","#1FC540"],
    edgecolor = "white",
    width = 0.5
)

plt.title("Supervivencia por sexo", fontsize= 14, fontweight= "bold")
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
supervivencia_clase = titanic_nuevo.groupby('clase')['sobrevivio'].mean()

plt.Figure(figsize=(7, 5))
supervivencia_clase.plot(
    kind = "bar",
    color = ["#DD8452","#1FC540", "#1505EF"],
    edgecolor = "white",
    width = 0.5
)

plt.title("Supervivencia por clase", fontsize= 14, fontweight= "bold")
plt.xlabel("clase")
# Out:
# Text(0.5, 0, 'clase')
